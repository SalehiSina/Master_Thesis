# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/MyDrive/Thesis/Projects/Steamboat_X/HEST")

# %%
# !pip install datasets
# !pip install huggingface_hub
# !pip install hf_xet

# %%
from huggingface_hub import login

login(token="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")

# %%
# Out:
# '/content'

# %%
import pandas as pd

local_dir='../../Data/hest_data' # hest will be dowloaded to this folder
os.makedirs(local_dir, exist_ok=True)

meta_df = pd.read_csv("hf://datasets/MahmoodLab/hest/HEST_v1_1_0.csv")

# %%
# Filter the dataframe by organ, oncotree code...
#meta_df = meta_df[meta_df['oncotree_code'] == 'IDC']
meta_df = meta_df[meta_df['organ'] == 'Pancreas']
meta_df = meta_df[meta_df['st_technology'] == 'Xenium']
meta_df = meta_df[meta_df['dataset_title'].str.contains('Multi')]
meta_df = meta_df[meta_df['id']=='TENX116']


ids_to_query = meta_df['id'].values

# %%
import os
import zipfile

from huggingface_hub import snapshot_download
from tqdm import tqdm


def download_hest(patterns, local_dir):
    repo_id = 'MahmoodLab/hest'
    snapshot_download(repo_id=repo_id, allow_patterns=patterns, repo_type="dataset", local_dir=local_dir)

    seg_dir = os.path.join(local_dir, 'cellvit_seg')
    if os.path.exists(seg_dir):
        print('Unzipping cell vit segmentation...')
        for filename in tqdm([s for s in os.listdir(seg_dir) if s.endswith('.zip')]):
            path_zip = os.path.join(seg_dir, filename)

            with zipfile.ZipFile(path_zip, 'r') as zip_ref:
                zip_ref.extractall(seg_dir)


list_patterns = [f"*{id}[_.]**" for id in ids_to_query]
download_hest(list_patterns, local_dir)
# Out:
# Fetching 17 files:   0%|          | 0/17 [00:00<?, ?it/s]
# pixel_size_vis/TENX116_pixel_size_vis.pn(…):   0%|          | 0.00/95.9k [00:00<?, ?B/s]
# patches/TENX116.h5:   0%|          | 0.00/320M [00:00<?, ?B/s]
# cellvit_seg/TENX116_cellvit_seg.geojson.(…):   0%|          | 0.00/30.9M [00:00<?, ?B/s]
# TENX116.json:   0%|          | 0.00/2.45k [00:00<?, ?B/s]
# st/TENX116.h5ad:   0%|          | 0.00/4.81M [00:00<?, ?B/s]
# spatial_plots/TENX116_spatial_plots.png:   0%|          | 0.00/116k [00:00<?, ?B/s]
# cellvit_seg/TENX116_cellvit_seg.parquet:   0%|          | 0.00/33.8M [00:00<?, ?B/s]
# patches_vis/TENX116_patch_vis.jpg:   0%|          | 0.00/257k [00:00<?, ?B/s]
# thumbnails/TENX116_downscaled_fullres.jp(…):   0%|          | 0.00/73.5k [00:00<?, ?B/s]
# TENX116_contours.geojson:   0%|          | 0.00/150k [00:00<?, ?B/s]
# tissue_seg/TENX116_vis.jpg:   0%|          | 0.00/634k [00:00<?, ?B/s]
# transcripts/TENX116_transcripts.parquet:   0%|          | 0.00/1.69G [00:00<?, ?B/s]
# wsis/TENX116.tif:   0%|          | 0.00/4.11G [00:00<?, ?B/s]
# xenium_seg/TENX116_xenium_cell_seg.geojs(…):   0%|          | 0.00/48.3M [00:00<?, ?B/s]
# xenium_seg/TENX116_xenium_nucleus_seg.pa(…):   0%|          | 0.00/40.4M [00:00<?, ?B/s]
# xenium_seg/TENX116_xenium_cell_seg.parqu(…):   0%|          | 0.00/40.3M [00:00<?, ?B/s]
# xenium_seg/TENX116_xenium_nucleus_seg.ge(…):   0%|          | 0.00/48.2M [00:00<?, ?B/s]
# Unzipping cell vit segmentation...
# 100%|██████████| 1/1 [00:09<00:00,  9.96s/it]
