# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install "scanpy==1.11.4"
# !pip install "squidpy"
# !pip install igraph
# !pip install leidenalg

# %%
# !pip install -U typing_extensions

# %%
import os
os.chdir("/content/drive/MyDrive/Thesis/Projects/Master_Thesis/")

# %%
import warnings

warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
import scanpy as sc

ad = sc.read_h5ad('./Data/Mouse_Brain/all_embeddings.h5ad')
ad

# %% [markdown]
# # Breast Cancer

# %% [markdown]
# ## leiden

# %%
# UNI

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'UNI' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# ... leiden ...
# 2026-07-07 21:20:11.267698: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-07 21:20:11.305469: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_UNI_segmentation_leiden
# Breast_Cancer_UNI_segmentation_leiden_ARI:  0.4093638327095699
#
#  Finished!

# %%
# h_optimus

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'h_optimus' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# ... leiden ...
# 2026-07-07 22:02:40.819818: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-07 22:02:40.868471: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_h_optimus_segmentation_leiden
# Breast_Cancer_h_optimus_segmentation_leiden_ARI:  0.21756710218184194
#
#  Finished!

# %%
# virchow

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'virchow' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# ... leiden ...
# 2026-07-07 22:29:18.772435: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-07 22:29:18.808709: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_virchow_segmentation_leiden
# Breast_Cancer_virchow_segmentation_leiden_ARI:  0.35200510488558023
#
#  Finished!

# %%
# ResNet50

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'ResNet50' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# ... leiden ...
# 2026-07-07 22:58:04.358646: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-07 22:58:04.411716: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_ResNet50_segmentation_leiden
# Breast_Cancer_ResNet50_segmentation_leiden_ARI:  0.08904055336655568
#
#  Finished!

# %%
# CNN_AE

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'CNN_AE' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# ... leiden ...
# 2026-07-08 00:03:06.294320: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-08 00:03:06.374770: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_CNN_AE_segmentation_leiden
# Breast_Cancer_CNN_AE_segmentation_leiden_ARI:  0.0
#
#  Finished!

# %%
# Genes

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'gene_Expression' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# ... leiden ...
# 2026-07-08 00:27:01.764883: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-08 00:27:01.800615: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_gene_Expression_segmentation_leiden
# Breast_Cancer_gene_Expression_segmentation_leiden_ARI:  0.08798074013408783
#
#  Finished!

# %%
# Modified_Steamboat UNI

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'Modified_Steamboat_UNI' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# ... leiden ...
# 2026-07-22 23:52:30.807787: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-22 23:52:30.879450: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_Modified_Steamboat_UNI_segmentation_leiden
# Breast_Cancer_Modified_Steamboat_UNI_segmentation_leiden_ARI:  0.18650542628032069
#
#  Finished!

# %%
# Modified_Steamboat MR NOISE

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'Modified_Steamboat_NOISE' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# ... leiden ...
# 2026-07-23 00:26:07.587414: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-23 00:26:07.674413: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_Modified_Steamboat_NOISE_segmentation_leiden
# Breast_Cancer_Modified_Steamboat_NOISE_segmentation_leiden_ARI:  0.1885768207722309
#
#  Finished!

# %%
# Modified_Steamboat MR NO Morpho

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'Modified_Steamboat_NOMORPHO' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# ... leiden ...
# 2026-07-23 01:06:31.851600: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-23 01:06:31.984766: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_Modified_Steamboat_NOMORPHO_segmentation_leiden
# Breast_Cancer_Modified_Steamboat_NOMORPHO_segmentation_leiden_ARI:  0.0746376576003071
#
# ...

# %%
# GNN MR UNI

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'GNN_UNI' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# ... leiden ...
# 2026-07-23 02:02:40.316829: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-23 02:02:40.418927: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_GNN_UNI_segmentation_leiden
# Breast_Cancer_GNN_UNI_segmentation_leiden_ARI:  0.19274737721396973
#
#  Finished!

# %%
# GNN MR NOISE

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'GNN_NOISE' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# ... leiden ...
# 2026-07-23 03:09:21.363221: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-23 03:09:21.513570: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_GNN_NOISE_segmentation_leiden
# Breast_Cancer_GNN_NOISE_segmentation_leiden_ARI:  0.1889694580814137
#
#  Finished!

# %%
# GNN MR NO Morpho

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'GNN_NOMORPHO' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# ... leiden ...
# 2026-07-23 03:47:43.468914: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-23 03:47:43.536503: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_GNN_NOMORPHO_segmentation_leiden
# Breast_Cancer_GNN_NOMORPHO_segmentation_leiden_ARI:  0.1985278292486372
#
#  Finished!

# %%
# PCA

# !python ./Results.py --dir '../Data/Breast_Cancer/all_embeddings_V3.h5ad' --name 'Breast_Cancer' --key 'concat_UNI' --label 'annotation' --operation 'leiden
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V3.h5ad
# ... leiden ...
# 2026-07-23 07:04:44.903388: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-23 07:04:46.690011: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Breast_Cancer_concat_UNI_segmentation_leiden
# Breast_Cancer_concat_UNI_segmentation_leiden_ARI:  0.2019550367063124
#
#  Finished!

# %% [markdown]
# ## k-means

# %%
# UNI

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'UNI' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# ... k-means clustering ...
# K =  4
# Inertia: 220347456.0
# Iterations run: 22
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Breast_Cancer_UNI_segmentation_kmeans
# Breast_Cancer_UNI_segmentation_kmeans_ARI:  0.3347280690086614
#
#  Finished!

# %%
# h_optimus

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'h_optimus' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# ... k-means clustering ...
# K =  4
# Inertia: 210990400.0
# Iterations run: 32
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Breast_Cancer_h_optimus_segmentation_kmeans
# Breast_Cancer_h_optimus_segmentation_kmeans_ARI:  0.04700921911489718
#
#  Finished!

# %%
# virchow

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'virchow' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# ... k-means clustering ...
# K =  4
# Inertia: 309292772.18680954
# Iterations run: 25
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Breast_Cancer_virchow_segmentation_kmeans
# Breast_Cancer_virchow_segmentation_kmeans_ARI:  0.0871894426651029
#
#  Finished!

# %%
# ResNet50

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'ResNet50' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# ... k-means clustering ...
# K =  4
# Inertia: 130467648.47325256
# Iterations run: 43
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Breast_Cancer_ResNet50_segmentation_kmeans
# Breast_Cancer_ResNet50_segmentation_kmeans_ARI:  0.05652931644529328
#
#  Finished!

# %%
# CNN_AE

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'CNN_AE' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# ... k-means clustering ...
# K =  4
# Inertia: 7683180.600980917
# Iterations run: 96
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Breast_Cancer_CNN_AE_segmentation_kmeans
# Breast_Cancer_CNN_AE_segmentation_kmeans_ARI:  -0.010350646464839262
#
#  Finished!

# %%
# Genes

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'gene_Expression' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# ... k-means clustering ...
# K =  4
# Inertia: 46288672.0
# Iterations run: 37
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Breast_Cancer_gene_Expression_segmentation_kmeans
# Breast_Cancer_gene_Expression_segmentation_kmeans_ARI:  0.09868701786696364
#
#  Finished!

# %%
# Modified_Steamboat UNI

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'Modified_Steamboat_UNI' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# ... k-means clustering ...
# K =  4
# Inertia: 6127705.0
# Iterations run: 19
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Breast_Cancer_Modified_Steamboat_UNI_segmentation_kmeans
# Breast_Cancer_Modified_Steamboat_UNI_segmentation_kmeans_ARI:  0.0784994827223812
#
#  Finished!

# %%
# Modified_Steamboat NOISE

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'Modified_Steamboat_NOISE' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# ... k-means clustering ...
# K =  4
# Inertia: 7315021.0
# Iterations run: 35
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Breast_Cancer_Modified_Steamboat_NOISE_segmentation_kmeans
# Breast_Cancer_Modified_Steamboat_NOISE_segmentation_kmeans_ARI:  0.21807767488062552
#
#  Finished!

# %%
# Modified_Steamboat No Morpho

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'Modified_Steamboat_NOMORPHO' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# ... k-means clustering ...
# K =  4
# Inertia: 5594911.0
# Iterations run: 30
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Breast_Cancer_Modified_Steamboat_NOMORPHO_segmentation_kmeans
# Breast_Cancer_Modified_Steamboat_NOMORPHO_segmentation_kmeans_ARI:  0.049666338241740986
#
#  Finished!

# %%
# GNN MR UNI

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'GNN_UNI' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# ... k-means clustering ...
# K =  4
# Inertia: 7490721.5
# Iterations run: 43
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Breast_Cancer_GNN_UNI_segmentation_kmeans
# Breast_Cancer_GNN_UNI_segmentation_kmeans_ARI:  0.09128652136353346
#
#  Finished!

# %%
# GNN MR NOISE

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'GNN_NOISE' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# ... k-means clustering ...
# K =  4
# Inertia: 7332325.5
# Iterations run: 43
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Breast_Cancer_GNN_NOISE_segmentation_kmeans
# Breast_Cancer_GNN_NOISE_segmentation_kmeans_ARI:  0.09129994213685712
#
#  Finished!

# %%
# GNN MR NO Morpho

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'GNN_NOMORPHO' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# ... k-means clustering ...
# K =  4
# Inertia: 7637289.0
# Iterations run: 24
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Breast_Cancer_GNN_NOMORPHO_segmentation_kmeans
# Breast_Cancer_GNN_NOMORPHO_segmentation_kmeans_ARI:  0.0710368909089628
#
#  Finished!

# %%
# PCA

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V3.h5ad' --name 'Breast_Cancer' --key 'concat_UNI' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V3.h5ad
# ... k-means clustering ...
# K =  4
# Inertia: 269148544.0
# Iterations run: 17
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Breast_Cancer_concat_UNI_segmentation_kmeans
# Breast_Cancer_concat_UNI_segmentation_kmeans_ARI:  0.1873461969118212
#
#  Finished!

# %% [markdown]
# ## UMAP

# %%
# UNI

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'UNI' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# ... UMAP ...
# 2026-07-07 20:53:28.216116: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-07 20:53:28.267568: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# this is new
#  saved in figures/Breast_Cancer_UNI_umap_UNI
#
#  Finished!

# %%
# h_optimus

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'h_optimus' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# ... UMAP ...
# 2026-07-07 20:57:36.872118: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-07 20:57:36.911669: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# this is new
#  saved in figures/Breast_Cancer_h_optimus_umap_h_optimus
#
#  Finished!

# %%
# virchow

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'virchow' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# ... UMAP ...
# 2026-07-07 21:00:29.331444: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-07 21:00:29.371676: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Breast_Cancer_virchow_umap_virchow
#
#  Finished!

# %%
# ResNet50

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'ResNet50' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# ... UMAP ...
# 2026-07-07 21:03:13.034859: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-07 21:03:13.075448: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Breast_Cancer_ResNet50_umap_ResNet50
#
#  Finished!

# %%
# CNN_AE

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'CNN_AE' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# ... UMAP ...
# 2026-07-07 21:05:56.163587: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-07 21:05:56.202576: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Breast_Cancer_CNN_AE_umap_CNN_AE
#
#  Finished!

# %%
# Genes

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'gene_Expression' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# ... UMAP ...
# 2026-07-07 21:08:46.869039: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-07 21:08:46.908737: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Breast_Cancer_gene_Expression_umap_gene_Expression
#
#  Finished!

# %%
# Modified_Steamboat UNI

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'Modified_Steamboat_UNI' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# ... UMAP ...
# 2026-07-22 23:42:23.567088: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-22 23:42:23.636848: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Breast_Cancer_Modified_Steamboat_UNI_umap_Modified_Steamboat_UNI
#
#  Finished!

# %%
# Modified_Steamboat NOISE

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'Modified_Steamboat_NOISE' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# ... UMAP ...
# 2026-07-22 23:05:22.445084: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-22 23:05:22.514935: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Breast_Cancer_Modified_Steamboat_NOISE_umap_Modified_Steamboat_NOISE
#
#  Finished!

# %%
# Modified_Steamboat No Morpho

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'Modified_Steamboat_NOMORPHO' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# ... UMAP ...
# 2026-07-22 23:10:49.197940: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-22 23:10:49.266721: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Breast_Cancer_Modified_Steamboat_NOMORPHO_umap_Modified_Steamboat_NOMORPHO
#
#  Finished!

# %%
# GNN UNI

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'GNN_UNI' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# ... UMAP ...
# 2026-07-22 23:15:42.877147: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-22 23:15:42.941767: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Breast_Cancer_GNN_UNI_umap_GNN_UNI
#
#  Finished!

# %%
# GNN No Morpho

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'GNN_NOMORPHO' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# ... UMAP ...
# 2026-07-22 23:20:53.955815: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-22 23:20:54.020039: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Breast_Cancer_GNN_NOMORPHO_umap_GNN_NOMORPHO
#
#  Finished!

# %%
# GNN NOISE

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'GNN_NOISE' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# ... UMAP ...
# 2026-07-22 23:26:00.567680: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-22 23:26:00.632419: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Breast_Cancer_GNN_NOISE_umap_GNN_NOISE
#
#  Finished!

# %%
# PCA

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V3.h5ad' --name 'Breast_Cancer' --key 'concat_UNI' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V3.h5ad
# ... UMAP ...
# 2026-07-23 07:41:34.526946: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-23 07:41:34.627590: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Breast_Cancer_concat_UNI_umap_concat_UNI
#
#  Finished!

# %% [markdown]
# ## Supervised Classification

# %%
# UNI

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'UNI' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=0.6951 | Train Acc=0.7735
# Epoch  20 | Loss=0.5211 | Train Acc=0.8207
# Epoch  30 | Loss=0.4295 | Train Acc=0.8456
# Epoch  40 | Loss=0.3786 | Train Acc=0.8623
# Epoch  50 | Loss=0.3406 | Train Acc=0.8781
#
# Test Accuracy: 0.8792
#
#               precision    recall  f1-score   support
#
#       DCIS_1       0.92      0.88      0.90     17414
#       DCIS_2       0.85      0.71      0.78     14785
#     Invasive       0.91      0.90      0.90     37401
#   unassigned       0.86      0.90      0.88     64624
#
#     accuracy                           0.88    134224
#    macro avg       0.89      0.85      0.87    134224
# weighted avg       0.88      0.88      0.88    134224
#
#
#  Finished!

# %%
# h_optimus

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'h_optimus' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=0.7316 | Train Acc=0.7647
# Epoch  20 | Loss=0.5461 | Train Acc=0.8112
# Epoch  30 | Loss=0.4582 | Train Acc=0.8323
# Epoch  40 | Loss=0.4045 | Train Acc=0.8534
# Epoch  50 | Loss=0.3680 | Train Acc=0.8673
#
# Test Accuracy: 0.8676
#
#               precision    recall  f1-score   support
#
#       DCIS_1       0.91      0.85      0.88     17414
#       DCIS_2       0.85      0.68      0.76     14785
#     Invasive       0.90      0.90      0.90     37401
#   unassigned       0.85      0.90      0.87     64624
#
#     accuracy                           0.87    134224
#    macro avg       0.87      0.83      0.85    134224
# weighted avg       0.87      0.87      0.87    134224
#
#
#  Finished!

# %%
# virchow

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'virchow' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=0.7795 | Train Acc=0.7231
# Epoch  20 | Loss=0.6136 | Train Acc=0.7987
# Epoch  30 | Loss=0.5183 | Train Acc=0.8211
# Epoch  40 | Loss=0.4618 | Train Acc=0.8342
# Epoch  50 | Loss=0.4221 | Train Acc=0.8466
#
# Test Accuracy: 0.8488
#
#               precision    recall  f1-score   support
#
#       DCIS_1       0.87      0.81      0.84     17414
#       DCIS_2       0.82      0.66      0.73     14785
#     Invasive       0.88      0.89      0.89     37401
#   unassigned       0.83      0.88      0.85     64624
#
#     accuracy                           0.85    134224
#    macro avg       0.85      0.81      0.83    134224
# weighted avg       0.85      0.85      0.85    134224
#
#
#  Finished!

# %%
# ResNet50

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'ResNet50' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=0.9808 | Train Acc=0.6153
# Epoch  20 | Loss=0.9104 | Train Acc=0.6458
# Epoch  30 | Loss=0.8577 | Train Acc=0.6687
# Epoch  40 | Loss=0.8173 | Train Acc=0.6859
# Epoch  50 | Loss=0.7840 | Train Acc=0.6984
#
# Test Accuracy: 0.6966
#
#               precision    recall  f1-score   support
#
#       DCIS_1       0.64      0.55      0.59     17414
#       DCIS_2       0.60      0.23      0.33     14785
#     Invasive       0.66      0.70      0.68     37401
#   unassigned       0.74      0.84      0.79     64624
#
#     accuracy                           0.70    134224
#    macro avg       0.66      0.58      0.60    134224
# weighted avg       0.69      0.70      0.68    134224
#
#
#  Finished!

# %%
# CNN_AE

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'CNN_AE' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=1.8040 | Train Acc=0.4524
# Epoch  20 | Loss=1.5140 | Train Acc=0.4328
# Epoch  30 | Loss=1.3549 | Train Acc=0.4473
# Epoch  40 | Loss=1.2794 | Train Acc=0.4630
# Epoch  50 | Loss=1.2406 | Train Acc=0.4772
#
# Test Accuracy: 0.4686
#
#               precision    recall  f1-score   support
#
#       DCIS_1       0.17      0.05      0.08     17414
#       DCIS_2       0.13      0.03      0.04     14785
#     Invasive       0.37      0.33      0.35     37401
#   unassigned       0.53      0.76      0.63     64624
#
#     accuracy                           0.47    134224
#    macro avg       0.30      0.29      0.28    134224
# weighted avg       0.40      0.47      0.41    134224
#
#
#  Finished!

# %%
# Genes

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'gene_Expression' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=0.9441 | Train Acc=0.6821
# Epoch  20 | Loss=0.7987 | Train Acc=0.7320
# Epoch  30 | Loss=0.7277 | Train Acc=0.7528
# Epoch  40 | Loss=0.6865 | Train Acc=0.7619
# Epoch  50 | Loss=0.6588 | Train Acc=0.7695
#
# Test Accuracy: 0.7619
#
#               precision    recall  f1-score   support
#
#       DCIS_1       0.83      0.67      0.74     17414
#       DCIS_2       0.73      0.37      0.49     14785
#     Invasive       0.83      0.80      0.81     37401
#   unassigned       0.72      0.86      0.78     64624
#
#     accuracy                           0.76    134224
#    macro avg       0.78      0.67      0.71    134224
# weighted avg       0.77      0.76      0.75    134224
#
#
#  Finished!

# %%
# Modified_Steamboat UNI

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'Modified_Steamboat_UNI' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=1.3405 | Train Acc=0.4815
# Epoch  20 | Loss=1.2935 | Train Acc=0.4815
# Epoch  30 | Loss=1.2466 | Train Acc=0.4815
# Epoch  40 | Loss=1.2038 | Train Acc=0.4815
# Epoch  50 | Loss=1.1705 | Train Acc=0.4815
#
# Test Accuracy: 0.4815
#
#               precision    recall  f1-score   support
#
#       DCIS_1       0.00      0.00      0.00     17414
#       DCIS_2       0.00      0.00      0.00     14785
#     Invasive       0.00      0.00      0.00     37401
#   unassigned       0.48      1.00      0.65     64624
#
#     accuracy                           0.48    134224
#    macro avg       0.12      0.25      0.16    134224
# weighted avg       0.23      0.48      0.31    134224
#
#
#  Finished!

# %%
# Modified_Steamboat NOISE

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'Modified_Steamboat_NOISE' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=1.3282 | Train Acc=0.4815
# Epoch  20 | Loss=1.2613 | Train Acc=0.4815
# Epoch  30 | Loss=1.1942 | Train Acc=0.4815
# Epoch  40 | Loss=1.1466 | Train Acc=0.4815
# Epoch  50 | Loss=1.1155 | Train Acc=0.4848
#
# Test Accuracy: 0.4948
#
#               precision    recall  f1-score   support
#
#       DCIS_1       0.00      0.00      0.00     17414
#       DCIS_2       0.00      0.00      0.00     14785
#     Invasive       0.92      0.05      0.10     37401
#   unassigned       0.49      1.00      0.66     64624
#
#     accuracy                           0.49    134224
#    macro avg       0.35      0.26      0.19    134224
# weighted avg       0.49      0.49      0.34    134224
#
#
#  Finished!

# %%
# Modified_Steamboat NO Morpho

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'Modified_Steamboat_NOMORPHO' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=1.3498 | Train Acc=0.4815
# Epoch  20 | Loss=1.3114 | Train Acc=0.4815
# Epoch  30 | Loss=1.2767 | Train Acc=0.4815
# Epoch  40 | Loss=1.2465 | Train Acc=0.4815
# Epoch  50 | Loss=1.2260 | Train Acc=0.4815
#
# Test Accuracy: 0.4815
#
#               precision    recall  f1-score   support
#
#       DCIS_1       0.00      0.00      0.00     17414
#       DCIS_2       0.00      0.00      0.00     14785
#     Invasive       0.00      0.00      0.00     37401
#   unassigned       0.48      1.00      0.65     64624
#
#     accuracy                           0.48    134224
#    macro avg       0.12      0.25      0.16    134224
# weighted avg       0.23      0.48      0.31    134224
#
#
#  Finished!

# %%
# GNN UNI

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'GNN_UNI' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=1.1633 | Train Acc=0.5064
# Epoch  20 | Loss=1.0563 | Train Acc=0.6076
# Epoch  30 | Loss=0.9930 | Train Acc=0.6022
# Epoch  40 | Loss=0.9469 | Train Acc=0.6292
# Epoch  50 | Loss=0.9026 | Train Acc=0.6719
#
# Test Accuracy: 0.6724
#
#               precision    recall  f1-score   support
#
#       DCIS_1       0.78      0.41      0.54     17414
#       DCIS_2       0.66      0.01      0.03     14785
#     Invasive       0.64      0.73      0.68     37401
#   unassigned       0.68      0.86      0.76     64624
#
#     accuracy                           0.67    134224
#    macro avg       0.69      0.50      0.50    134224
# weighted avg       0.68      0.67      0.63    134224
#
#
#  Finished!

# %%
# GNN NOISE

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'GNN_NOISE' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=1.1376 | Train Acc=0.5755
# Epoch  20 | Loss=1.0273 | Train Acc=0.6063
# Epoch  30 | Loss=0.9638 | Train Acc=0.6137
# Epoch  40 | Loss=0.9146 | Train Acc=0.6615
# Epoch  50 | Loss=0.8659 | Train Acc=0.6894
#
# Test Accuracy: 0.6891
#
#               precision    recall  f1-score   support
#
#       DCIS_1       0.63      0.56      0.59     17414
#       DCIS_2       0.86      0.01      0.03     14785
#     Invasive       0.72      0.73      0.73     37401
#   unassigned       0.68      0.85      0.76     64624
#
#     accuracy                           0.69    134224
#    macro avg       0.72      0.54      0.53    134224
# weighted avg       0.71      0.69      0.65    134224
#
#
#  Finished!

# %%
# GNN No Morpho

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V2.h5ad' --name 'Breast_Cancer' --key 'GNN_NOMORPHO' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V2.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=1.1601 | Train Acc=0.5298
# Epoch  20 | Loss=1.0421 | Train Acc=0.6144
# Epoch  30 | Loss=0.9669 | Train Acc=0.6171
# Epoch  40 | Loss=0.9125 | Train Acc=0.6599
# Epoch  50 | Loss=0.8638 | Train Acc=0.6937
#
# Test Accuracy: 0.6930
#
#               precision    recall  f1-score   support
#
#       DCIS_1       0.63      0.53      0.58     17414
#       DCIS_2       0.66      0.03      0.06     14785
#     Invasive       0.72      0.74      0.73     37401
#   unassigned       0.69      0.86      0.77     64624
#
#     accuracy                           0.69    134224
#    macro avg       0.68      0.54      0.53    134224
# weighted avg       0.69      0.69      0.65    134224
#
#
#  Finished!

# %%
# PCA

# !python ./Results.py --dir './Data/Breast_Cancer/all_embeddings_V3.h5ad' --name 'Breast_Cancer' --key 'concat_UNI' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Breast_Cancer/all_embeddings_V3.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=0.6262 | Train Acc=0.7968
# Epoch  20 | Loss=0.4461 | Train Acc=0.8377
# Epoch  30 | Loss=0.3755 | Train Acc=0.8607
# Epoch  40 | Loss=0.3306 | Train Acc=0.8796
# Epoch  50 | Loss=0.2968 | Train Acc=0.8938
#
# Test Accuracy: 0.8906
#
#               precision    recall  f1-score   support
#
#       DCIS_1       0.94      0.90      0.92     17414
#       DCIS_2       0.87      0.73      0.79     14785
#     Invasive       0.91      0.91      0.91     37401
#   unassigned       0.87      0.91      0.89     64624
#
#     accuracy                           0.89    134224
#    macro avg       0.90      0.86      0.88    134224
# weighted avg       0.89      0.89      0.89    134224
#
#
#  Finished!

# %% [markdown]
# # Mouse Brain

# %% [markdown]
# ## leiden

# %%
# UNI

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'UNI' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings.h5ad
# ... leiden ...
# 2026-07-12 23:08:44.424959: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-12 23:08:44.462854: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_UNI_segmentation_leiden
# Mouse_Brain_UNI_segmentation_leiden_ARI:  0.6606694266464824
#
#  Finished!

# %%
# h_optimus

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'h_optimus' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings.h5ad
# ... leiden ...
# 2026-07-12 23:11:33.037687: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-12 23:11:33.075626: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_h_optimus_segmentation_leiden
# Mouse_Brain_h_optimus_segmentation_leiden_ARI:  0.3396472806410536
#
#  Finished!

# %%
# virchow

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'virchow' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings.h5ad
# ... leiden ...
# 2026-07-12 23:14:22.330897: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-12 23:14:22.374116: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_virchow_segmentation_leiden
# Mouse_Brain_virchow_segmentation_leiden_ARI:  0.45903625259862935
#
#  Finished!

# %%
# ResNet50

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'ResNet50' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_2.h5ad
# ... leiden ...
# 2026-07-13 09:16:48.954363: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-13 09:16:50.297220: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_ResNet50_segmentation_leiden
# Mouse_Brain_ResNet50_segmentation_leiden_ARI:  0.15290022888262692
#
#  Finished!

# %%
# Genes

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'gene_Expression' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings.h5ad
# ... leiden ...
# 2026-07-12 23:17:07.355951: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-12 23:17:07.394003: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_gene_Expression_segmentation_leiden
# Mouse_Brain_gene_Expression_segmentation_leiden_ARI:  0.2566405974111059
#
#  Finished!

# %%
# Modified_Steamboat UNI

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'Modified_Steamboat_UNI' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# ... leiden ...
# 2026-07-22 22:39:39.239036: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-22 22:39:39.302963: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_Modified_Steamboat_UNI_segmentation_leiden
# Mouse_Brain_Modified_Steamboat_UNI_segmentation_leiden_ARI:  0.30957601823335307
#
#  Finished!

# %%
# Modified_Steamboat NOISE

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'Modified_Steamboat_NOISE' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# ... leiden ...
# 2026-07-22 22:43:02.220582: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-22 22:43:02.285471: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_Modified_Steamboat_NOISE_segmentation_leiden
# Mouse_Brain_Modified_Steamboat_NOISE_segmentation_leiden_ARI:  0.12920245885795426
#
#  Finished!

# %%
# Modified_Steamboat NO Morpho

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'Modified_Steamboat_NOMORPHO' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# ... leiden ...
# 2026-07-22 22:47:07.615922: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-22 22:47:07.684667: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_Modified_Steamboat_NOMORPHO_segmentation_leiden
# Mouse_Brain_Modified_Steamboat_NOMORPHO_segmentation_leiden_ARI:  0.2017928518842462
#
#  Finished!

# %%
# GNN UNI

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'GNN_UNI' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# ... leiden ...
# 2026-07-22 22:50:38.163807: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-22 22:50:38.226272: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_GNN_UNI_segmentation_leiden
# Mouse_Brain_GNN_UNI_segmentation_leiden_ARI:  0.3470317774794836
#
#  Finished!

# %%
# GNN NOISE

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'GNN_NOISE' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# ... leiden ...
# 2026-07-22 22:53:46.670073: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-22 22:53:46.735794: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_GNN_NOISE_segmentation_leiden
# Mouse_Brain_GNN_NOISE_segmentation_leiden_ARI:  0.3013795422611253
#
#  Finished!

# %%
# GNN No Morpho

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'GNN_NOMORPHO' --label 'annotation' --operation 'leiden'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# ... leiden ...
# 2026-07-22 22:57:25.156721: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-22 22:57:25.235217: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_annotation
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in figures/Mouse_Brain_GNN_NOMORPHO_segmentation_leiden
# Mouse_Brain_GNN_NOMORPHO_segmentation_leiden_ARI:  0.34923137105301516
#
#  Finished!

# %%
# PCA

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V3.h5ad' --name 'Mouse_Brain' --key 'concat_UNI' --label 'annotation' --operation 'leiden'

# %% [markdown]
# ## k-means

# %%
# UNI

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'UNI' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings.h5ad
# ... k-means clustering ...
# K =  6
# Inertia: 21781094.0
# Iterations run: 33
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Mouse_Brain_UNI_segmentation_kmeans
# Mouse_Brain_UNI_segmentation_kmeans_ARI:  0.4182298594260965
#
#  Finished!

# %%
# h_optimus

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'h_optimus' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings.h5ad
# ... k-means clustering ...
# K =  6
# Inertia: 18631812.0
# Iterations run: 27
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Mouse_Brain_h_optimus_segmentation_kmeans
# Mouse_Brain_h_optimus_segmentation_kmeans_ARI:  0.5010788961667147
#
#  Finished!

# %%
# virchow

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'virchow' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings.h5ad
# ... k-means clustering ...
# K =  6
# Inertia: 30892356.503267195
# Iterations run: 60
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Mouse_Brain_virchow_segmentation_kmeans
# Mouse_Brain_virchow_segmentation_kmeans_ARI:  0.32453550939136455
#
#  Finished!

# %%
# ResNet50

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'ResNet50' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_2.h5ad
# ... k-means clustering ...
# K =  6
# Inertia: 13921361.971641513
# Iterations run: 74
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Mouse_Brain_ResNet50_segmentation_kmeans
# Mouse_Brain_ResNet50_segmentation_kmeans_ARI:  0.1952568220031642
#
#  Finished!

# %%
# Genes

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'gene_Expression' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings.h5ad
# ... k-means clustering ...
# K =  6
# Inertia: 85529352.0
# Iterations run: 35
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Mouse_Brain_gene_Expression_segmentation_kmeans
# Mouse_Brain_gene_Expression_segmentation_kmeans_ARI:  0.06852158097023356
#
#  Finished!

# %%
# Modified_Steamboat UNI

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'Modified_Steamboat_UNI' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# ... k-means clustering ...
# K =  6
# Inertia: 681158.5
# Iterations run: 21
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Mouse_Brain_Modified_Steamboat_UNI_segmentation_kmeans
# Mouse_Brain_Modified_Steamboat_UNI_segmentation_kmeans_ARI:  0.3624469312902211
#
#  Finished!

# %%
# Modified_Steamboat NOISE

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'Modified_Steamboat_NOISE' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# ... k-means clustering ...
# K =  6
# Inertia: 304913.8125
# Iterations run: 26
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Mouse_Brain_Modified_Steamboat_NOISE_segmentation_kmeans
# Mouse_Brain_Modified_Steamboat_NOISE_segmentation_kmeans_ARI:  0.1634397185806242
#
#  Finished!

# %%
# Modified_Steamboat NO Morpho

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'Modified_Steamboat_NOMORPHO' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# ... k-means clustering ...
# K =  6
# Inertia: 634077.75
# Iterations run: 50
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Mouse_Brain_Modified_Steamboat_NOMORPHO_segmentation_kmeans
# Mouse_Brain_Modified_Steamboat_NOMORPHO_segmentation_kmeans_ARI:  0.12422059292118952
#
#  Finished!

# %%
# GNN UNI

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'GNN_UNI' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# ... k-means clustering ...
# K =  6
# Inertia: 545237.625
# Iterations run: 25
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Mouse_Brain_GNN_UNI_segmentation_kmeans
# Mouse_Brain_GNN_UNI_segmentation_kmeans_ARI:  0.07597926733845627
#
#  Finished!

# %%
# GNN NOISE

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'GNN_NOISE' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# ... k-means clustering ...
# K =  6
# Inertia: 599244.3125
# Iterations run: 24
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Mouse_Brain_GNN_NOISE_segmentation_kmeans
# Mouse_Brain_GNN_NOISE_segmentation_kmeans_ARI:  0.20395917105973596
#
#  Finished!

# %%
# GNN No Morpho

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'GNN_NOMORPHO' --label 'annotation' --operation 'k-means'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# ... k-means clustering ...
# K =  6
# Inertia: 669304.25
# Iterations run: 24
# Done!
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# saved in : figures/Mouse_Brain_GNN_NOMORPHO_segmentation_kmeans
# Mouse_Brain_GNN_NOMORPHO_segmentation_kmeans_ARI:  0.2222599478120531
#
#  Finished!

# %%
# PCA

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V3.h5ad' --name 'Mouse_Brain' --key 'concat_UNI' --label 'annotation' --operation 'k-means'

# %% [markdown]
# ## UMAP

# %%
# UNI

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'UNI' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings.h5ad
# ... UMAP ...
# 2026-07-12 22:13:22.503866: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-12 22:13:22.546690: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Mouse_Brain_UNI_umap_UNI
#
#  Finished!

# %%
# h_optimus

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'h_optimus' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings.h5ad
# ... UMAP ...
# 2026-07-12 22:15:42.447123: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-12 22:15:42.489526: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Mouse_Brain_h_optimus_umap_h_optimus
#
#  Finished!

# %%
# virchow

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'virchow' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings.h5ad
# ... UMAP ...
# 2026-07-12 22:17:06.594281: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-12 22:17:06.639004: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Mouse_Brain_virchow_umap_virchow
#
#  Finished!

# %%
# ResNet50

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'ResNet50' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_2.h5ad
# ... UMAP ...
# 2026-07-13 09:19:09.668443: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-13 09:19:09.708929: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Mouse_Brain_ResNet50_umap_ResNet50
#
#  Finished!

# %%
# Genes

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'gene_Expression' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings.h5ad
# ... UMAP ...
# 2026-07-12 22:18:48.359817: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-12 22:18:48.402337: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Mouse_Brain_gene_Expression_umap_gene_Expression
#
#  Finished!

# %%
# Modified_Steamboat UNI

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'Modified_Steamboat_UNI' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# ... UMAP ...
# 2026-07-22 22:28:51.335109: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-22 22:28:53.241267: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Mouse_Brain_Modified_Steamboat_UNI_umap_Modified_Steamboat_UNI
#
#  Finished!

# %%
# Modified_Steamboat NOISE

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'Modified_Steamboat_NOISE' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# ... UMAP ...
# 2026-07-22 22:30:30.979891: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-22 22:30:31.047128: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Mouse_Brain_Modified_Steamboat_NOISE_umap_Modified_Steamboat_NOISE
#
#  Finished!

# %%
# Modified_Steamboat NO Morpho

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'Modified_Steamboat_NOMORPHO' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# ... UMAP ...
# 2026-07-22 22:32:06.949062: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-22 22:32:07.018414: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Mouse_Brain_Modified_Steamboat_NOMORPHO_umap_Modified_Steamboat_NOMORPHO
#
#  Finished!

# %%
# GNN UNI

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'GNN_UNI' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# ... UMAP ...
# 2026-07-22 22:33:44.989649: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-22 22:33:45.057024: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Mouse_Brain_GNN_UNI_umap_GNN_UNI
#
#  Finished!

# %%
# GNN NOISE

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'GNN_NOISE' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# ... UMAP ...
# 2026-07-22 22:35:29.142782: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-22 22:35:29.212756: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Mouse_Brain_GNN_NOISE_umap_GNN_NOISE
#
#  Finished!

# %%
# GNN No Morpho

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'GNN_NOMORPHO' --label 'annotation' --operation 'UMAP'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# ... UMAP ...
# 2026-07-22 22:37:23.957031: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-22 22:37:24.047392: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  saved in figures/Mouse_Brain_GNN_NOMORPHO_umap_GNN_NOMORPHO
#
#  Finished!

# %%
# PCA

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V3.h5ad' --name 'Mouse_Brain' --key 'concat_UNI' --label 'annotation' --operation 'UMAP'

# %% [markdown]
# ## Supervised Classification

# %%
# UNI

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'UNI' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=0.5960 | Train Acc=0.8533
# Epoch  20 | Loss=0.3026 | Train Acc=0.8968
# Epoch  30 | Loss=0.2169 | Train Acc=0.9279
# Epoch  40 | Loss=0.1696 | Train Acc=0.9453
# Epoch  50 | Loss=0.1380 | Train Acc=0.9552
#
# Test Accuracy: 0.9333
#
#               precision    recall  f1-score   support
#
#           CA       0.99      0.98      0.99      1455
#           DG       1.00      0.99      0.99      1594
# Iso_Cortex_1       0.85      0.85      0.85      2736
# Iso_Cortex_2       0.88      0.89      0.89      3431
#           TH       0.97      0.97      0.97      2963
#  fiber_track       0.97      0.97      0.97      2740
#
#     accuracy                           0.93     14919
#    macro avg       0.94      0.94      0.94     14919
# weighted avg       0.93      0.93      0.93     14919
#
#
#  Finished!

# %%
# h_optimus

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'h_optimus' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=0.5104 | Train Acc=0.8099
# Epoch  20 | Loss=0.3398 | Train Acc=0.8726
# Epoch  30 | Loss=0.2625 | Train Acc=0.9040
# Epoch  40 | Loss=0.2176 | Train Acc=0.9244
# Epoch  50 | Loss=0.1855 | Train Acc=0.9399
#
# Test Accuracy: 0.9151
#
#               precision    recall  f1-score   support
#
#           CA       0.99      0.97      0.98      1455
#           DG       1.00      0.98      0.99      1594
# Iso_Cortex_1       0.81      0.80      0.81      2736
# Iso_Cortex_2       0.84      0.87      0.86      3431
#           TH       0.97      0.97      0.97      2963
#  fiber_track       0.97      0.95      0.96      2740
#
#     accuracy                           0.92     14919
#    macro avg       0.93      0.93      0.93     14919
# weighted avg       0.92      0.92      0.92     14919
#
#
#  Finished!

# %%
# virchow

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'virchow' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=0.7840 | Train Acc=0.7200
# Epoch  20 | Loss=0.4847 | Train Acc=0.8201
# Epoch  30 | Loss=0.3866 | Train Acc=0.8547
# Epoch  40 | Loss=0.3334 | Train Acc=0.8780
# Epoch  50 | Loss=0.2970 | Train Acc=0.8925
#
# Test Accuracy: 0.8822
#
#               precision    recall  f1-score   support
#
#           CA       0.97      0.96      0.97      1455
#           DG       0.99      0.97      0.98      1594
# Iso_Cortex_1       0.75      0.74      0.75      2736
# Iso_Cortex_2       0.80      0.83      0.82      3431
#           TH       0.94      0.96      0.95      2963
#  fiber_track       0.95      0.91      0.93      2740
#
#     accuracy                           0.88     14919
#    macro avg       0.90      0.90      0.90     14919
# weighted avg       0.88      0.88      0.88     14919
#
#
#  Finished!

# %%
# ResNet50

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'ResNet50' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_2.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=1.0644 | Train Acc=0.6447
# Epoch  20 | Loss=0.7708 | Train Acc=0.7168
# Epoch  30 | Loss=0.6395 | Train Acc=0.7621
# Epoch  40 | Loss=0.5613 | Train Acc=0.7873
# Epoch  50 | Loss=0.5092 | Train Acc=0.8048
#
# Test Accuracy: 0.7917
#
#               precision    recall  f1-score   support
#
#           CA       0.87      0.87      0.87      1455
#           DG       0.94      0.89      0.91      1594
# Iso_Cortex_1       0.62      0.53      0.57      2736
# Iso_Cortex_2       0.69      0.79      0.74      3431
#           TH       0.85      0.88      0.87      2963
#  fiber_track       0.91      0.86      0.88      2740
#
#     accuracy                           0.79     14919
#    macro avg       0.81      0.80      0.81     14919
# weighted avg       0.79      0.79      0.79     14919
#
#
#  Finished!

# %%
# Genes

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'gene_Expression' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=0.7336 | Train Acc=0.8399
# Epoch  20 | Loss=0.4149 | Train Acc=0.9289
# Epoch  30 | Loss=0.2712 | Train Acc=0.9584
# Epoch  40 | Loss=0.1806 | Train Acc=0.9780
# Epoch  50 | Loss=0.1255 | Train Acc=0.9903
#
# Test Accuracy: 0.8870
#
#               precision    recall  f1-score   support
#
#           CA       0.99      0.94      0.96      1455
#           DG       1.00      0.94      0.97      1594
# Iso_Cortex_1       0.78      0.80      0.79      2736
# Iso_Cortex_2       0.87      0.87      0.87      3431
#           TH       0.94      0.93      0.93      2963
#  fiber_track       0.85      0.90      0.87      2740
#
#     accuracy                           0.89     14919
#    macro avg       0.90      0.89      0.90     14919
# weighted avg       0.89      0.89      0.89     14919
#
#
#  Finished!

# %%
# Modified_Steamboat UNI

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'Modified_Steamboat_UNI' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=1.7652 | Train Acc=0.2116
# Epoch  20 | Loss=1.7405 | Train Acc=0.3250
# Epoch  30 | Loss=1.7140 | Train Acc=0.4138
# Epoch  40 | Loss=1.6838 | Train Acc=0.4940
# Epoch  50 | Loss=1.6481 | Train Acc=0.5087
#
# Test Accuracy: 0.5018
#
#               precision    recall  f1-score   support
#
#           CA       0.00      0.00      0.00      1455
#           DG       0.00      0.00      0.00      1594
# Iso_Cortex_1       0.00      0.00      0.00      2736
# Iso_Cortex_2       0.34      0.97      0.50      3431
#           TH       0.80      0.95      0.87      2963
#  fiber_track       0.86      0.50      0.63      2740
#
#     accuracy                           0.50     14919
#    macro avg       0.33      0.40      0.33     14919
# weighted avg       0.40      0.50      0.40     14919
#
#
#  Finished!

# %%
# Modified_Steamboat NOISE

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'Modified_Steamboat_NOISE' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=1.7340 | Train Acc=0.2660
# Epoch  20 | Loss=1.6897 | Train Acc=0.3484
# Epoch  30 | Loss=1.6409 | Train Acc=0.3639
# Epoch  40 | Loss=1.5844 | Train Acc=0.3687
# Epoch  50 | Loss=1.5296 | Train Acc=0.3725
#
# Test Accuracy: 0.3634
#
#               precision    recall  f1-score   support
#
#           CA       0.00      0.00      0.00      1455
#           DG       0.00      0.00      0.00      1594
# Iso_Cortex_1       0.00      0.00      0.00      2736
# Iso_Cortex_2       0.30      0.80      0.44      3431
#           TH       0.33      0.39      0.36      2963
#  fiber_track       0.66      0.56      0.60      2740
#
#     accuracy                           0.36     14919
#    macro avg       0.22      0.29      0.23     14919
# weighted avg       0.26      0.36      0.28     14919
#
#
#  Finished!

# %%
# Modified_Steamboat NO Morpho

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'Modified_Steamboat_NOMORPHO' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=1.7713 | Train Acc=0.1834
# Epoch  20 | Loss=1.7587 | Train Acc=0.2301
# Epoch  30 | Loss=1.7507 | Train Acc=0.2301
# Epoch  40 | Loss=1.7475 | Train Acc=0.2301
# Epoch  50 | Loss=1.7470 | Train Acc=0.2301
#
# Test Accuracy: 0.2300
#
#               precision    recall  f1-score   support
#
#           CA       0.00      0.00      0.00      1455
#           DG       0.00      0.00      0.00      1594
# Iso_Cortex_1       0.00      0.00      0.00      2736
# Iso_Cortex_2       0.23      1.00      0.37      3431
#           TH       0.00      0.00      0.00      2963
#  fiber_track       0.00      0.00      0.00      2740
#
#     accuracy                           0.23     14919
#    macro avg       0.04      0.17      0.06     14919
# weighted avg       0.05      0.23      0.09     14919
#
#
#  Finished!

# %%
# GNN UNI

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'GNN_UNI' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=1.5507 | Train Acc=0.4655
# Epoch  20 | Loss=1.3823 | Train Acc=0.5272
# Epoch  30 | Loss=1.2342 | Train Acc=0.5621
# Epoch  40 | Loss=1.1008 | Train Acc=0.6680
# Epoch  50 | Loss=0.9815 | Train Acc=0.7380
#
# Test Accuracy: 0.7399
#
#               precision    recall  f1-score   support
#
#           CA       0.99      0.59      0.74      1455
#           DG       0.95      0.81      0.88      1594
# Iso_Cortex_1       0.67      0.39      0.49      2736
# Iso_Cortex_2       0.59      0.89      0.71      3431
#           TH       0.86      0.86      0.86      2963
#  fiber_track       0.74      0.81      0.78      2740
#
#     accuracy                           0.74     14919
#    macro avg       0.80      0.73      0.74     14919
# weighted avg       0.76      0.74      0.73     14919
#
#
#  Finished!

# %%
# GNN NOISE

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'GNN_NOISE' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=1.8053 | Train Acc=0.2301
# Epoch  20 | Loss=1.7608 | Train Acc=0.1834
# Epoch  30 | Loss=1.7542 | Train Acc=0.2301
# Epoch  40 | Loss=1.7470 | Train Acc=0.2301
# Epoch  50 | Loss=1.7473 | Train Acc=0.2301
#
# Test Accuracy: 0.2300
#
#               precision    recall  f1-score   support
#
#           CA       0.00      0.00      0.00      1455
#           DG       0.00      0.00      0.00      1594
# Iso_Cortex_1       0.00      0.00      0.00      2736
# Iso_Cortex_2       0.23      1.00      0.37      3431
#           TH       0.00      0.00      0.00      2963
#  fiber_track       0.00      0.00      0.00      2740
#
#     accuracy                           0.23     14919
#    macro avg       0.04      0.17      0.06     14919
# weighted avg       0.05      0.23      0.09     14919
#
#
#  Finished!

# %%
# GNN No Morpho

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V2.h5ad' --name 'Mouse_Brain' --key 'GNN_NOMORPHO' --label 'annotation' --operation 'Supervised'
# Out:
# Using CPU
# Loading anndata object ...
#
# Location:  ../Data/Mouse_Brain/all_embeddings_V2.h5ad
# Classification Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch  10 | Loss=1.5062 | Train Acc=0.5106
# Epoch  20 | Loss=1.3068 | Train Acc=0.5835
# Epoch  30 | Loss=1.1298 | Train Acc=0.6828
# Epoch  40 | Loss=0.9738 | Train Acc=0.7541
# Epoch  50 | Loss=0.8428 | Train Acc=0.7860
#
# Test Accuracy: 0.7961
#
#               precision    recall  f1-score   support
#
#           CA       0.98      0.77      0.86      1455
#           DG       0.99      0.88      0.93      1594
# Iso_Cortex_1       0.71      0.59      0.65      2736
# Iso_Cortex_2       0.71      0.84      0.77      3431
#           TH       0.87      0.86      0.86      2963
#  fiber_track       0.76      0.84      0.79      2740
#
#     accuracy                           0.80     14919
#    macro avg       0.83      0.80      0.81     14919
# weighted avg       0.80      0.80      0.80     14919
#
#
#  Finished!

# %%
# PCA

# !python ./Results.py --dir './Data/Mouse_Brain/all_embeddings_V3.h5ad' --name 'Mouse_Brain' --key 'concat_UNI' --label 'annotation' --operation 'Supervised'
